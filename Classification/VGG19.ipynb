# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs=4

# %%
path = '/home/spriyanshu723/biomedical/Mask_with_2class/'

# %%
data = (ImageList.from_folder(path).split_by_rand_pct().label_from_folder().databunch(bs=bs))
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (5216 items)
# x: ImageList
# Image (3, 400, 500),Image (3, 400, 500),Image (3, 400, 500),Image (3, 400, 500),Image (3, 400, 500)
# y: CategoryList
# Benign,Benign,Benign,Benign,Benign
# Path: /home/spriyanshu723/biomedical/Mask_with_2class;
#
# Valid: LabelList (1304 items)
# x: ImageList
# Image (3, 400, 500),Image (3, 400, 500),Image (3, 400, 500),Image (3, 400, 500),Image (3, 400, 500)
# y: CategoryList
# Benign,Malignant,Benign,Benign,Malignant
# Path: /home/spriyanshu723/biomedical/Mask_with_2class;
#
# Test: None

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
data.classes
# Out:
# ['Benign', 'Malignant']

# %% [markdown]
# ## TRAINING

# %%
learn = cnn_learner(data, models.vgg19_bn, metrics=error_rate)

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace)
#       (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (9): ReLU(inplace)
#       (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (12): ReLU(inplace)
# ...

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=1e-2)
# Out:
# Total time: 06:48 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.634628</td>
#       <td>0.915089</td>
#       <td>0.279141</td>
#       <td>03:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.485689</td>
#       <td>4.946218</td>
#       <td>0.175613</td>
#       <td>03:24</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.save('class_vgg19_1')

# %%
learn.fit_one_cycle(4, max_lr=1e-2)
# Out:
# Total time: 13:36 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.617457</td>
#       <td>4.397887</td>
#       <td>0.324387</td>
#       <td>03:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.561106</td>
#       <td>18.893047</td>
#       <td>0.477761</td>
#       <td>03:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.443336</td>
#       <td>1.825046</td>
#       <td>0.331288</td>
#       <td>03:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.393042</td>
#       <td>3.765317</td>
#       <td>0.168712</td>
#       <td>03:23</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.save('class_vgg19_2')

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-6, 1e-5))
# Out:
# Total time: 06:47 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.455649</td>
#       <td>0.909181</td>
#       <td>0.167945</td>
#       <td>03:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.479648</td>
#       <td>1.178871</td>
#       <td>0.143405</td>
#       <td>03:23</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.save('class_vgg19_3')

# %%
learn.fit_one_cycle(2, max_lr=slice(5e-6, 5e-5))
# Out:
# Total time: 06:47 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.454455</td>
#       <td>1.270298</td>
#       <td>0.167178</td>
#       <td>03:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.376536</td>
#       <td>1.575295</td>
#       <td>0.177914</td>
#       <td>03:23</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.save('class_vgg19_4')

# %%
learn.fit_one_cycle(2, max_lr=1e-4)
# Out:
# Total time: 06:47 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.367495</td>
#       <td>1.465267</td>
#       <td>0.223926</td>
#       <td>03:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.443227</td>
#       <td>1.324892</td>
#       <td>0.132669</td>
#       <td>03:23</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.save('class_vgg19_4')

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-5, 1e-4))
# Out:
# Total time: 09:06 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.424845</td>
#       <td>0.684369</td>
#       <td>0.142638</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.395189</td>
#       <td>0.391138</td>
#       <td>0.130368</td>
#       <td>04:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.save('class_vgg19_6')

# %%
learn.fit_one_cycle(2, max_lr=1e-6)
# Out:
# Total time: 09:06 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.411163</td>
#       <td>0.911233</td>
#       <td>0.127301</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.385687</td>
#       <td>0.846238</td>
#       <td>0.124233</td>
#       <td>04:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.save('class_vgg19_7')

# %%
learn.fit_one_cycle(2, max_lr=1e-6)
# Out:
# Total time: 09:06 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.354324</td>
#       <td>1.108342</td>
#       <td>0.134969</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.394606</td>
#       <td>0.581962</td>
#       <td>0.118865</td>
#       <td>04:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.save('class_vgg19_8')

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-6, 1e-5))
# Out:
# Total time: 09:06 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.400687</td>
#       <td>1.796181</td>
#       <td>0.138804</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.413319</td>
#       <td>0.600050</td>
#       <td>0.118098</td>
#       <td>04:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.save('class_vgg19_9')

# %%
learn.fit_one_cycle(2, max_lr=1e-6)
# Out:
# Total time: 09:06 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.376409</td>
#       <td>0.807347</td>
#       <td>0.125767</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.395734</td>
#       <td>1.788170</td>
#       <td>0.129601</td>
#       <td>04:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.save('class_vgg19_10')

# %%
learn.fit_one_cycle(8, max_lr=slice(1e-6,1e-4))
# Out:
# Total time: 36:27 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.387676</td>
#       <td>0.364280</td>
#       <td>0.111963</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.418139</td>
#       <td>0.435748</td>
#       <td>0.115031</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.315528</td>
#       <td>0.427456</td>
#       <td>0.100460</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.376103</td>
#       <td>0.508204</td>
#       <td>0.101994</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.329754</td>
#       <td>1.551613</td>
#       <td>0.103528</td>
#       <td>04:33</td>
#     </tr>
# ...

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.save('class_vgg16_11')

# %%
learn.fit_one_cycle(8, max_lr=slice(1e-6,1e-5))
# Out:
# Total time: 36:28 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.301802</td>
#       <td>0.590330</td>
#       <td>0.081288</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.342291</td>
#       <td>0.889307</td>
#       <td>0.078221</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.337676</td>
#       <td>0.956202</td>
#       <td>0.088957</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.316316</td>
#       <td>0.348575</td>
#       <td>0.088957</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.303010</td>
#       <td>0.565668</td>
#       <td>0.085890</td>
#       <td>04:33</td>
#     </tr>
# ...

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.save('class_vgg16_12')

# %%
learn.fit_one_cycle(2, max_lr=1e-6)
# Out:
# Total time: 09:06 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.263715</td>
#       <td>0.735104</td>
#       <td>0.065951</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.304474</td>
#       <td>0.872291</td>
#       <td>0.087423</td>
#       <td>04:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.save('class_vgg19_13')

# %%
learn.load('class_vgg16_12')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (5216 items)
# x: ImageList
# Image (3, 400, 500),Image (3, 400, 500),Image (3, 400, 500),Image (3, 400, 500),Image (3, 400, 500)
# y: CategoryList
# Benign,Benign,Benign,Benign,Benign
# Path: /home/spriyanshu723/biomedical/Mask_with_2class;
#
# Valid: LabelList (1304 items)
# x: ImageList
# Image (3, 400, 500),Image (3, 400, 500),Image (3, 400, 500),Image (3, 400, 500),Image (3, 400, 500)
# y: CategoryList
# Benign,Malignant,Benign,Benign,Malignant
# Path: /home/spriyanshu723/biomedical/Mask_with_2class;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(2, max_lr=1e-6)
# Out:
# Total time: 09:07 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.310219</td>
#       <td>0.611139</td>
#       <td>0.088190</td>
#       <td>04:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.302440</td>
#       <td>0.893595</td>
#       <td>0.072086</td>
#       <td>04:34</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Result

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img=cv.imread('/home/spriyanshu723/biomedical/size_GT_Output/000035_0_1565.jpg')

# %%
plt.imshow(img)

# %%
import numpy as np

# %%
np.count_nonzero(img == 127)
# Out:
# 3

# %%
img[img > 127]=255
img[img <= 127]=0

# %%
plt.imshow(img)

# %%
np.count_nonzero(img == 255)
# Out:
# 6564

# %%
img[img == 1] = 27

# %%
plt.imshow(img)

# %% [markdown]
# ## Improving Mask

# %%
for i in os.listdir('/home/spriyanshu723/biomedical/size_GT_Output/'):
    a = str(i)
    img = cv.imread('/home/spriyanshu723/biomedical/size_GT_Output/'+a)
    img[img > 127]=255
    img[img <= 127]=0
    img[img==255]=1
    img[img==2] = 1
    plt.imsave('/home/spriyanshu723/biomedical/new_size_GT_Output/'+a,img)

# %%
# !ls '/home/spriyanshu723/biomedical/new_size_GT_Output/'
# Out:
# 000001_0_1462.jpg  000041_0_7174.jpg  000082_0_4211.jpg  000123_0_2773.jpg
# 000001_0_1565.jpg  000041_0_7563.jpg  000082_0_4549.jpg  000123_0_2862.jpg
# 000001_0_1646.jpg  000041_0_7818.jpg  000082_0_4665.jpg  000123_0_2945.jpg
# 000001_0_1651.jpg  000041_0_8147.jpg  000082_0_4909.jpg  000123_0_3239.jpg
# 000001_0_1881.jpg  000041_0_8744.jpg  000082_0_5646.jpg  000123_0_3448.jpg
# 000001_0_2015.jpg  000041_0_8880.jpg  000082_0_5786.jpg  000123_0_3462.jpg
# 000001_0_2065.jpg  000041_0_9165.jpg  000082_0_6238.jpg  000123_0_3678.jpg
# 000001_0_263.jpg   000041_0_9224.jpg  000082_0_6378.jpg  000123_0_3725.jpg
# 000001_0_266.jpg   000041_0_9386.jpg  000082_0_6721.jpg  000123_0_3834.jpg
# 000001_0_2718.jpg  000041_0_9450.jpg  000082_0_6854.jpg  000123_0_4122.jpg
# 000001_0_2773.jpg  000042_0_1462.jpg  000082_0_7174.jpg  000123_0_4211.jpg
# 000001_0_2862.jpg  000042_0_1565.jpg  000082_0_7563.jpg  000123_0_4549.jpg
# ...

# %%
b = cv.imread('/home/spriyanshu723/biomedical/new_size_GT_Output/000042_0_263.jpg')
plt.imshow(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5a1c3e257980> in <module>
# ----> 1 b = cv.imread('/home/spriyanshu723/biomedical/new_size_GT_Output/000042_0_263.jpg')
#       2 plt.imshow(b)
#
# NameError: name 'cv' is not defined

# %%
np.count_nonzero(b == 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-05dcaf9ac674> in <module>
# ----> 1 np.count_nonzero(b == 0)
#
# NameError: name 'np' is not defined

# %%
np.count_nonzero(b == 255)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a32e97c3d35c> in <module>
# ----> 1 np.count_nonzero(b == 255)
#
# NameError: name 'np' is not defined

# %%
np.count_nonzero(b == 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-760a1a72724c> in <module>
# ----> 1 np.count_nonzero(b == 1)
#
# NameError: name 'np' is not defined
